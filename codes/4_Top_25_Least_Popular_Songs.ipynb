# %%
# Reading The Files From The First Notebook.
# %run 1_Importing_Dataset.ipynb

# %% [markdown]
# ### Top 10 Least Popular Songs On Spotify

# %%
"""
Selecting the top 25 tracks with the lowest popularity from the dataset (data)
Then sorting the output in ascending order by popularity
Then finally limiting the number of tracks by using head(25)
"""
least = df.sort_values('track_popularity').head(25)

# Printing the results.
least
# Out:
#                       album_id  \
# 0       4zH8bbEjLe0Gdbv2FVLjnK
# 126219  12ZR62SZNvBcK9hQj5WrnY
# 126220  12ZR62SZNvBcK9hQj5WrnY
# 277331  6VJlI4EydcM5Fb61iLbUKe
# 126223  7DzDCGtplc0PbLvLKTo1uI
# 126224  7DzDCGtplc0PbLvLKTo1uI
# 126225  7DzDCGtplc0PbLvLKTo1uI
# 126227  12ZR62SZNvBcK9hQj5WrnY
# 277332  6VJlI4EydcM5Fb61iLbUKe
# 126228  7DzDCGtplc0PbLvLKTo1uI
# 126230  12ZR62SZNvBcK9hQj5WrnY
# 126231  7DzDCGtplc0PbLvLKTo1uI
# 126232  12ZR62SZNvBcK9hQj5WrnY
# 277330  6VJlI4EydcM5Fb61iLbUKe
# 126234  12ZR62SZNvBcK9hQj5WrnY
# 126235  12ZR62SZNvBcK9hQj5WrnY
# 126236  7DzDCGtplc0PbLvLKTo1uI
# 126229  12ZR62SZNvBcK9hQj5WrnY
# 126237  12ZR62SZNvBcK9hQj5WrnY
# 277333  6VJlI4EydcM5Fb61iLbUKe
# 277335  6VJlI4EydcM5Fb61iLbUKe
# 277351  6VJlI4EydcM5Fb61iLbUKe
# 277350  6VJlI4EydcM5Fb61iLbUKe
# 277349  6VJlI4EydcM5Fb61iLbUKe
# 277348  6VJlI4EydcM5Fb61iLbUKe
#
#                                             album_name  album_popularity  \
# ...

# %%
# Declaring the specific columns of interest to be extracted from the previous DataFrame.
columns = ['artist_0', 'track_name', 'track_popularity','release_year', 'release_month']

# Printing the results while setting the index of the resulting DataFrame to the 'track_name' column.
least[columns].set_index('track_name')
# Out:
#                                                       artist_0  \
# track_name
# Intro                                                       AB
# I Need Thee/I'M Yours Everyday (Reprise)          Chris Bethel
# High Places                                       Chris Bethel
# Sleep Music                               Spa Music Relaxation
# Endless Love                                      Chris Bethel
# High Places                                       Chris Bethel
# Then Came You (Extended Version)                  Chris Bethel
# Monologue (Destined 4 Worship)                   brian gregory
# Easy Going                                Spa Music Relaxation
# You Are Good                                      Chris Bethel
# My Eyes Are On You                                Chris Bethel
# Without You                                       Chris Bethel
# No One Compares 2 U                               Chris Bethel
# Warm Feelings Inside                      Spa Music Relaxation
# ...
