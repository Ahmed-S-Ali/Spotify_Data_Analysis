# %%
# Reading The Files From The First Notebook.
# %run 1_Importing_Dataset.ipynb

# %% [markdown]
# ### Data Collection and Preprocessing

# %%
# Rows And Columns Numbers of Spotify Data.
df.shape
# Out:
# (375141, 49)

# %%
# The First Few DataFrame of Spotify Data.
df.head()
# Out:
#                  album_id   album_name  album_popularity album_type  \
# 0  4zH8bbEjLe0Gdbv2FVLjnK  Son Of Tabu                 1      album
# 1  4zH8bbEjLe0Gdbv2FVLjnK  Son Of Tabu                 1      album
# 2  4zH8bbEjLe0Gdbv2FVLjnK  Son Of Tabu                 1      album
# 3  4zH8bbEjLe0Gdbv2FVLjnK  Son Of Tabu                 1      album
# 4  4zH8bbEjLe0Gdbv2FVLjnK  Son Of Tabu                 1      album
#
#               artists artist_0  artist_1 artist_2 artist_3 artist_4  ...  \
# 0              ['AB']       AB       NaN      NaN      NaN      NaN  ...
# 1  ['AB', '22nd Jim']       AB  22nd Jim      NaN      NaN      NaN  ...
# 2     ['AB', 'Veeze']       AB     Veeze      NaN      NaN      NaN  ...
# 3              ['AB']       AB       NaN      NaN      NaN      NaN  ...
# 4              ['AB']       AB       NaN      NaN      NaN      NaN  ...
#
#   time_signature                                         track_href  \
# ...

# %%
# The Last Few DataFrame of Spotify Data.
df.tail()
# Out:
#                       album_id  \
# 375136  1MPAXuTVL2Ej5x0JHiSPq8
# 375137  6fyR4wBPwLHKcRtxgd4sGh
# 375138  7mzrIsaAjnXihW3InKjlC3
# 375139  11gfxXxJPd3j6sdWUyEA5S
# 375140  19O46pvAPG1Xg6fxAuSU5F
#
#                                             album_name  album_popularity  \
# 375136  Reputation Stadium Tour Surprise Song Playlist                76
# 375137                       Speak Now World Tour Live                60
# 375138                                    Taylor Swift                75
# 375139                       Taylor Swift Karaoke: Red                20
# 375140                Midnights (The Til Dawn Edition)                61
#
#        album_type                         artists      artist_0    artist_1  \
# 375136      album                ['Taylor Swift']  Taylor Swift         NaN
# 375137      album                ['Taylor Swift']  Taylor Swift         NaN
# 375138      album                ['Taylor Swift']  Taylor Swift         NaN
# ...

# %%
# Checking NULL Values Of Spotify Data.
df.isnull().sum()
# Out:
# album_id                  0
# album_name                1
# album_popularity          0
# album_type                0
# artists                   0
# artist_0                  2
# artist_1             288062
# artist_2             336841
# artist_3             361318
# artist_4             369054
# artist_id                 0
# duration_sec              0
# label                    52
# release_date             22
# total_tracks              0
# track_id                  0
# track_name                5
# track_number              0
# artist_genres             0
# artist_popularity         0
# followers                 0
# name                      0
# genre_0              165278
# genre_1              255655
# genre_2              297922
# genre_3              326531
# genre_4              343824
# acousticness            777
# analysis_url            777
# danceability            777
# duration_ms             777
# energy                  777
# instrumentalness        777
# ...

# %%
# Inspecting The Columns' Names, Data types And Et Cetera.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375141 entries, 0 to 375140
# Data columns (total 49 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   album_id           375141 non-null  object
#  1   album_name         375140 non-null  object
#  2   album_popularity   375141 non-null  int64
#  3   album_type         375141 non-null  object
#  4   artists            375141 non-null  object
#  5   artist_0           375139 non-null  object
#  6   artist_1           87079 non-null   object
#  7   artist_2           38300 non-null   object
#  8   artist_3           13823 non-null   object
#  9   artist_4           6087 non-null    object
#  10  artist_id          375141 non-null  object
#  11  duration_sec       375141 non-null  float64
#  12  label              375089 non-null  object
#  13  release_date       375119 non-null  object
#  14  total_tracks       375141 non-null  int64
# ...

# %%
# Calculating Basic Statistics for Numerical Columns of Spotify Artists.
df.describe().transpose()
# Out:
#                       count          mean           std     min          25%  \
# album_popularity   375141.0  1.713202e+01  2.037102e+01     0.0       1.0000
# duration_sec       375141.0  2.154278e+02  1.257274e+02     0.0     159.7000
# total_tracks       375141.0  1.825871e+01  2.667469e+01     1.0       8.0000
# track_number       375141.0  8.039367e+00  8.089265e+00     1.0       2.0000
# artist_popularity  375141.0  2.934655e+01  2.625059e+01     0.0       5.0000
# followers          375141.0  2.282646e+06  9.635135e+06     0.0     250.0000
# acousticness       374364.0  3.856914e-01  3.590716e-01     0.0       0.0389
# danceability       374364.0  5.723293e-01  1.908158e-01     0.0       0.4520
# duration_ms        374364.0  2.155215e+05  1.166461e+05  3056.0  160000.0000
# energy             374364.0  5.248086e-01  2.641695e-01     0.0       0.3190
# instrumentalness   374364.0  2.644226e-01  3.792366e-01     0.0       0.0000
# ...
